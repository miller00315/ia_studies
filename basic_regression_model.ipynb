# %% [markdown]
# <a href="https://colab.research.google.com/github/miller00315/ia_studies/blob/main/basic_regression_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing libraries

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow import lite

# %% [markdown]
# # Preparing Dataset

# %%
x = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
y = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# # Creating Neural Network

# %%
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # Model training

# %%
model.fit(x, y, epochs=250)
# Out:
# Epoch 1/250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0198
# Epoch 2/250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0194
# Epoch 3/250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0190
# Epoch 4/250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0186
# Epoch 5/250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0183
# Epoch 6/250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0179
# Epoch 7/250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0175
# Epoch 8/250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0172
# Epoch 9/250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0168
# Epoch 10/250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0165
# Epoch 11/250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0161
# Epoch 12/250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0158
# Epoch 13/250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0155
# Epoch 14/250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0152
# Epoch 15/250
# ...

# %% [markdown]
# # Model testing

# %%
model.predict(np.array([100]).reshape(1, -1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# array([[198.56435]], dtype=float32)

# %% [markdown]
# # Model conversion

# %%
coonverter = tf.lite.TFLiteConverter.from_keras_model(model)

tflite_model = coonverter.convert()

with open("linear.tflite", "wb") as f:
  f.write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmpn2805aap'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 1), dtype=tf.float32, name='keras_tensor_7')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   139763511387136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139763511388016: TensorSpec(shape=(), dtype=tf.resource, name=None)
