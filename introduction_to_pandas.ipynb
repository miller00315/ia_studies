# %% [markdown]
# <a href="https://colab.research.google.com/github/miller00315/ia_studies/blob/main/introduction_to_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#2 main datatypes
series = pd.Series(['BMW', 'Toyota', 'Honda'])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# seria = 1-dimensional

# %%
colours = pd.Series(['red', 'blue', 'white'])

# %%
colours
# Out:
# 0      red
# 1     blue
# 2    white
# dtype: object

# %%
# Dataframe = 2-dimensional

car_data = pd.DataFrame({'Car make': series, 'Colour': colours})

# %%
car_data
# Out:
#   Car make Colour
# 0      BMW    red
# 1   Toyota   blue
# 2    Honda  white

# %%
#import data
car_sales_datraframe = pd.read_csv('car-sales.csv')

car_sales_datraframe
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
 car_sales_datraframe.to_csv("exported_car_sales.csv", index=False)

# %%
exported_car_sales_datraframe = pd.read_csv('exported_car_sales.csv')

exported_car_sales_datraframe
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# **Describe data**

# %%
# Attribute
car_sales_datraframe.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns = car_sales_datraframe.columns

car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales_datraframe.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales_datraframe.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales_datraframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_prices = pd.Series([3000, 1500, 111250])

car_prices.mean()
# Out:
# 38583.333333333336

# %%
car_sales_datraframe.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales_datraframe['Doors'].sum()
# Out:
# 40

# %%
len(car_sales_datraframe)
# Out:
# 10

# %% [markdown]
# **Viewing and selecting data**

# %%
car_sales_datraframe.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales_datraframe
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_datraframe.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
#.loc e & .iloc

animals = pd.Series(['cat', 'dog', 'bird', 'panda', 'snake'], index=[0, 3, 9, 8, 3])

#animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
#.loc refers to index
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales_datraframe.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
#.iloc refers to position

animals.iloc[3]
# Out:
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales_datraframe.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales_datraframe.iloc[1:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales_datraframe['Make']
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales_datraframe[car_sales_datraframe['Make'] == 'Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales_datraframe[car_sales_datraframe['Odometer (KM)'] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales_datraframe
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales_datraframe['Make'], car_sales_datraframe['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
#gropy by
car_sales_datraframe.groupby(['Make'])[['Odometer (KM)', 'Doors']].mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW           11179.0    5.0
# Honda         54738.0    4.0
# Nissan       122347.5    4.0
# Toyota        79606.5    4.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales_datraframe['Odometer (KM)'].plot()
# Out:
# <Axes: >

# %%
car_sales_datraframe['Odometer (KM)'].hist()
# Out:
# <Axes: >

# %%
car_sales_datraframe['Price'] = car_sales_datraframe['Price'].str.replace('$', '')

# %%
car_sales_datraframe['Price'] = car_sales_datraframe['Price'].str.replace('.', '')

# %%
car_sales_datraframe['Price'] = car_sales_datraframe['Price'].str.replace(',', '').astype(int)

# %%
car_sales_datraframe['Price'].plot()
# Out:
# <Axes: >

# %%
car_sales_datraframe['Price']
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: int64

# %% [markdown]
# **Manipulating data**

# %%
car_sales_dataframe = pd.read_csv('car-sales.csv')

# %%
car_sales_dataframe['Make'].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales_dataframe['Make'] = car_sales_dataframe['Make'].str.lower()

car_sales_datraframe
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
car_sales_missing = pd.read_csv('car-sales-missing-data.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv('car-sales-missing-data.csv')

# %%
car_sales_missing.dropna(inplace=True)

# %%
#Colun from series

seats_column = pd.Series([5,5,5,5,5])


car_sales_dataframe['Seats'] = seats_column

car_sales_dataframe
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fule per 100KM
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  Toyota  Green          99213      4   $4,500.00    NaN             4.7
# 6   Honda   Blue          45698      4   $7,500.00    NaN             7.6
# 7   Honda   Blue          54738      4   $7,000.00    NaN             8.7
# 8  Toyota  White          60000      4   $6,250.00    NaN             3.0
# 9  Nissan  White          31600      4   $9,700.00    NaN             4.5

# %%
car_sales_dataframe['Seats'].fillna(5, inplace=True)

# %%
car_sales_dataframe
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fule per 100KM
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   Honda   Blue          45698      4   $7,500.00    5.0             7.6
# 7   Honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  Toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.5

# %%
#Column frfom Python list

fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]

car_sales_dataframe['Fuel per 100KM'] = fuel_economy

car_sales_dataframe
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fule per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   Honda   Blue          45698      4   $7,500.00    5.0             7.6
# 7   Honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  Toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.5
#
#    Fuel per 100KM
# 0             7.5
# 1             9.2
# 2             5.0
# 3             9.6
# 4             8.7
# 5             4.7
# ...

# %%
car_sales_dataframe['Total fuel used'] = car_sales_dataframe["Odometer (KM)"] / 100 * car_sales_dataframe["Fuel per 100KM"]

car_sales_dataframe
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fule per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   Honda   Blue          45698      4   $7,500.00    5.0             7.6
# 7   Honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  Toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.5
#
#    Fuel per 100KM  Total fuel used
# 0             7.5        11253.225
# 1             9.2         8086.708
# 2             5.0         1627.450
# ...

# %%
# create  a column form a single value

car_sales_dataframe["Number of wheels"] = 4

car_sales_dataframe
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fule per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   Honda   Blue          45698      4   $7,500.00    5.0             7.6
# 7   Honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  Toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.5
#
#    Fuel per 100KM  Total fuel used  Number of wheels
# 0             7.5        11253.225                 4
# ...

# %%
car_sales_dataframe["Passed road safety"] = True

car_sales_dataframe
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fule per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   Honda   Blue          45698      4   $7,500.00    5.0             7.6
# 7   Honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  Toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.5
#
#    Fuel per 100KM  Total fuel used  Number of wheels  Passed road safety
# 0             7.5        11253.225                 4                True
# ...

# %%
car_sales_dataframe = car_sales_dataframe.drop('Fuel per 100KM', axis=1)

car_sales_dataframe
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Total fuel used  \
# 0  Toyota  White         150043      4   $4,000.00    5.0        11253.225
# 1   Honda    Red          87899      4   $5,000.00    5.0         8086.708
# 2  Toyota   Blue          32549      3   $7,000.00    5.0         1627.450
# 3     BMW  Black          11179      5  $22,000.00    5.0         1073.184
# 4  Nissan  White         213095      4   $3,500.00    5.0        18539.265
# 5  Toyota  Green          99213      4   $4,500.00    5.0         4663.011
# 6   Honda   Blue          45698      4   $7,500.00    5.0         3473.048
# 7   Honda   Blue          54738      4   $7,000.00    5.0         4762.206
# 8  Toyota  White          60000      4   $6,250.00    5.0         1800.000
# 9  Nissan  White          31600      4   $9,700.00    5.0         1422.000
#
#    Number of wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# ...

# %%
car_sales_dataframe_shuffled = car_sales_dataframe.sample(frac=1)

car_sales_dataframe_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Total fuel used  \
# 7   Honda   Blue          54738      4   $7,000.00    5.0         4762.206
# 2  Toyota   Blue          32549      3   $7,000.00    5.0         1627.450
# 9  Nissan  White          31600      4   $9,700.00    5.0         1422.000
# 5  Toyota  Green          99213      4   $4,500.00    5.0         4663.011
# 1   Honda    Red          87899      4   $5,000.00    5.0         8086.708
# 6   Honda   Blue          45698      4   $7,500.00    5.0         3473.048
# 8  Toyota  White          60000      4   $6,250.00    5.0         1800.000
# 4  Nissan  White         213095      4   $3,500.00    5.0        18539.265
# 0  Toyota  White         150043      4   $4,000.00    5.0        11253.225
# 3     BMW  Black          11179      5  $22,000.00    5.0         1073.184
#
#    Number of wheels  Passed road safety
# 7                 4                True
# 2                 4                True
# ...

# %%
car_sales_dataframe_shuffled.sample(frac=0.1)
# Out:
#     Make Colour  Odometer (KM)  Doors      Price  Seats  Total fuel used  \
# 6  Honda   Blue          45698      4  $7,500.00    5.0         3473.048
#
#    Number of wheels  Passed road safety
# 6                 4                True

# %%
car_sales_dataframe_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_dataframe_shuffled = car_sales_dataframe_shuffled.drop('index', axis=1)

# %%
car_sales_dataframe_shuffled['Odometer (KM)'] = car_sales_dataframe_shuffled['Odometer (KM)'].apply(lambda x: x / 1.6)

car_sales_dataframe_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Total fuel used  \
# 0   Honda   Blue      34211.250      4   $7,000.00    5.0         4762.206
# 1  Toyota   Blue      20343.125      3   $7,000.00    5.0         1627.450
# 2  Nissan  White      19750.000      4   $9,700.00    5.0         1422.000
# 3  Toyota  Green      62008.125      4   $4,500.00    5.0         4663.011
# 4   Honda    Red      54936.875      4   $5,000.00    5.0         8086.708
# 5   Honda   Blue      28561.250      4   $7,500.00    5.0         3473.048
# 6  Toyota  White      37500.000      4   $6,250.00    5.0         1800.000
# 7  Nissan  White     133184.375      4   $3,500.00    5.0        18539.265
# 8  Toyota  White      93776.875      4   $4,000.00    5.0        11253.225
# 9     BMW  Black       6986.875      5  $22,000.00    5.0         1073.184
#
#    Number of wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# ...

# %%
car_sales_datraframe.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
heart_disease = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
car
