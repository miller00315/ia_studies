# %% [markdown]
# <a href="https://colab.research.google.com/github/miller00315/ia_studies/blob/main/tecnicas_avan%C3%A7adas_clusters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
import numpy as np
from sklearn.preprocessing import scale
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
from hopkins import *
from metric import *
from visual_assessment_of_tendency import *

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
iris = datasets.load_iris()

clust1 = scale(iris.data)
clust2= scale(np.random.rand(150, 4))

# %%
inertia = []

for i in range(1, 8):
    kmeans = KMeans(n_clusters=i, n_init='auto')
    kmeans.fit(clust1)
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 8), inertia)
plt.title("Elbow")
plt.show()

# %%
hopkins(clust1, 150)
# Out:
# 0.17768423303760164

# %%
hopkins(clust2, 150)
# Out:
# 0.5119547082903031

# %%
vat(clust1)

# %%
vat(clust2)

# %%
ivat(clust1)

# %%
ivat(clust2)

# %%
m = assess_tendency_by_metric(clust1, 'silhouette', 5)

print(m)
# Out:
# (2, array([0.58175005, 0.45937792, 0.38349897, 0.34503345]))

# %%
m = assess_tendency_by_metric(clust1, 'davies_bouldin', 5)

print(m)
# Out:
# (2, array([0.59331269, 0.83400015, 0.86981437, 0.94171179]))

# %%
m = assess_tendency_by_metric(clust1, 'calinski_harabasz', 5)

print(m)
# Out:
# (2, array([251.34933946, 241.89326237, 207.25483719, 203.26823296]))

# %%
m = assess_tendency_by_metric(clust2, 'silhouette', 5)


print(m)
# Out:
# (5, array([0.1931564 , 0.20413824, 0.21711356, 0.23603892]))

# %%
m = assess_tendency_by_metric(clust2, 'davies_bouldin', 5)

print(m)
# Out:
# (5, array([1.89948791, 1.55690811, 1.39357166, 1.30258441]))

# %%
m = assess_tendency_by_metric(clust2, 'calinski_harabasz', 5)

print(m)
# Out:
# (5, array([38.02713233, 38.64948476, 39.49156899, 39.91311732]))

# %%
m = assess_tendency_by_mean_metric_score(clust1, 5)

print(m)
# Out:
# 2.0

# %%
m = assess_tendency_by_mean_metric_score(clust2, 5)

print(m)
# Out:
# 4.666666666666667
