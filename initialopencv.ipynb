# %% [markdown]
# <a href="https://colab.research.google.com/github/miller00315/ia_studies/blob/main/initialopencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install opencv-python

# %%
import numpy as np
import cv2
print("OpenCV-Python Version {}".format(cv2.__version__))
# Out:
# OpenCV-Python Version 4.10.0

# %%
from skimage import io
import matplotlib.pyplot as plt

# reading the sample image from a url
image = io.imread('https://farrokhkarimi.github.io/images/gallery/modals/ice-m.jpg')
plt.imshow(image)
plt.show()

# %%
# saving the image on the disk
io.imsave('image.jpg', image)

# loading the image from the disk
image = cv2.imread('image.jpg')

plt.imshow(image)
plt.show()

# %%
import sys
import cv2 as cv

# %%
from google.colab.patches import cv2_imshow

img = cv2.imread('image.jpg', cv2.IMREAD_GRAYSCALE)
rows, cols = img.shape

sobel_horizontal = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=5)
sobel_vertical = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=5)

cv2_imshow(img)
cv2_imshow(sobel_horizontal)
cv2_imshow(sobel_vertical)

cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=1080x817>
# <PIL.Image.Image image mode=L size=1080x817>
# <PIL.Image.Image image mode=L size=1080x817>
# -1
