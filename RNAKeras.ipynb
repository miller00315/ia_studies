# %% [markdown]
# <a href="https://colab.research.google.com/github/miller00315/ia_studies/blob/main/RNAKeras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
df = pd.read_csv('Churn_treino.csv', sep=";")

df
# Out:
#       CreditScore Geography  Gender  Age  Tenure   Balance  NumOfProducts  \
# 0             619    France  Female   42       2         0              1
# 1             608     Spain  Female   41       1   8380786              1
# 2             502    France  Female   42       8   1596608              3
# 3             699    France  Female   39       1         0              2
# 4             850     Spain  Female   43       2  12551082              1
# ...           ...       ...     ...  ...     ...       ...            ...
# 9995          771    France    Male   39       5         0              2
# 9996          516    France    Male   35      10   5736961              1
# 9997          709    France  Female   36       7         0              1
# 9998          772   Germany    Male   42       3   7507531              2
# 9999          792    France  Female   28       4  13014279              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
X = df.drop('Exited', axis=1)

y = df['Exited']

# %% [markdown]
# Padronizando as colunas numericas

# %%
standardScaler = StandardScaler()


numerical = X.select_dtypes(include=['int64', 'float64']).columns


X[numerical] = standardScaler.fit_transform(X[numerical])

# %%
X
# Out:
#       CreditScore Geography  Gender       Age    Tenure   Balance  \
# 0       -0.326221    France  Female  0.293517 -1.041760 -1.110553
# 1       -0.440036     Spain  Female  0.198164 -1.387538  0.222782
# 2       -1.536794    France  Female  0.293517  1.032908 -0.856542
# 3        0.501521    France  Female  0.007457 -1.387538 -1.110553
# 4        2.063884     Spain  Female  0.388871 -1.041760  0.886252
# ...           ...       ...     ...       ...       ...       ...
# 9995     1.246488    France    Male  0.007457 -0.004426 -1.110553
# 9996    -1.391939    France    Male -0.373958  1.724464 -0.197835
# 9997     0.604988    France  Female -0.278604  0.687130 -1.110553
# 9998     1.256835   Germany    Male  0.293517 -0.695982  0.083852
# 9999     1.463771    France  Female -1.041433 -0.350204  0.959944
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0         -0.911583   0.646092        0.970243         0.170614
# ...

# %% [markdown]
# Padronizando as colunas categóricas (essas colunas não podem ser padronizadas então deve ser realizado posterior a padronização das colunas numéricas)

# %%
labelEncoder = LabelEncoder()

categorical = X.select_dtypes(include='object').columns


for col in categorical:
  X[col] = labelEncoder.fit_transform(X[col])

# %% [markdown]
# Dados normalizados:

# %%
X
# Out:
#       CreditScore  Geography  Gender       Age    Tenure   Balance  \
# 0       -0.326221          0       0  0.293517 -1.041760 -1.110553
# 1       -0.440036          2       0  0.198164 -1.387538  0.222782
# 2       -1.536794          0       0  0.293517  1.032908 -0.856542
# 3        0.501521          0       0  0.007457 -1.387538 -1.110553
# 4        2.063884          2       0  0.388871 -1.041760  0.886252
# ...           ...        ...     ...       ...       ...       ...
# 9995     1.246488          0       1  0.007457 -0.004426 -1.110553
# 9996    -1.391939          0       1 -0.373958  1.724464 -0.197835
# 9997     0.604988          0       0 -0.278604  0.687130 -1.110553
# 9998     1.256835          1       1  0.293517 -0.695982  0.083852
# 9999     1.463771          0       0 -1.041433 -0.350204  0.959944
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0         -0.911583   0.646092        0.970243         0.170614
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=0)

# %%
model = Sequential()

model.add(Dense(units=64, activation='relu', input_dim=X_train.shape[1]))
model.add(Dropout(0.4))
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(units=64, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 219/219 [==============================] - 3s 4ms/step - loss: 0.5348 - accuracy: 0.7593
# Epoch 2/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.4665 - accuracy: 0.8020
# Epoch 3/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4478 - accuracy: 0.8087
# Epoch 4/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4341 - accuracy: 0.8161
# Epoch 5/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4165 - accuracy: 0.8210
# Epoch 6/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.8324
# Epoch 7/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.4029 - accuracy: 0.8279
# Epoch 8/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3980 - accuracy: 0.8309
# Epoch 9/50
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3903 - accuracy: 0.8407
# Epoch 10/50
# ...

# %%
previsoes = model.predict(X_test)

previsoes
# Out:
# 94/94 [==============================] - 1s 4ms/step
# array([[0.32009855],
#        [0.29540834],
#        [0.21107742],
#        ...,
#        [0.05836258],
#        [0.09708346],
#        [0.51313335]], dtype=float32)

# %%
y_pred = (previsoes > 0.5).astype('int32')

y_pred
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [1]], dtype=int32)

# %%
print('Acurracia: ', accuracy_score(y_test, y_pred))
print('F1: ', f1_score(y_test, y_pred))
print('Recall: ', recall_score(y_test, y_pred))
print('Matrix de confusão: ', confusion_matrix(y_test, y_pred))
# Out:
# Acurracia:  0.856
# F1:  0.5789473684210527
# Recall:  0.4782608695652174
# Matrix de confusão:  [[2271  108]
#  [ 324  297]]
